# %%
# coding: utf-8

import tweepy
import pandas as pd
from langdetect import detect
from datetime import datetime 
from datetime import timedelta
from dotenv import load_dotenv
from pathlib import Path  # Python 3.6+ only
env_path = Path('../.env') 
load_dotenv(dotenv_path=env_path)
import os

consumer_key = os.getenv("CONSUMER_KEY")
consumer_secret = os.getenv("CONSUMER_SECRET")
access_key = os.getenv("ACCESS_KEY")
access_secret = os.getenv("ACCESS_SECRET")

auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_key, access_secret) 
api = tweepy.API(auth) 

screenname = ["narendramodi","WHO","CDCgov","COVID19CA","CovidIndiaSeva","UK COVID-19","COVID19_USA_","ashishkjha","COVIDNewsByMIB","MoHFW_INDIA"]

tweet,tweets_dates,text_query,hyperlinks,screennames_twitter = [], [], ["CORONA","COVID"], [], []

count = 0
for i in screenname:
    tweets = api.user_timeline(screen_name=i,count=50,tweet_mode="extended")  
    for status in tweets:
        for text in text_query:
            if text in status.full_text and detect(status.full_text)=="en" and "RT" not in status.full_text:
                tweet.append(status.full_text)
                tweets_dates.append(status.created_at)
                screennames_twitter.append('@'+status.user.screen_name)
                if len(status.entities['urls']) >0:
                    hyperlinks.append(status.entities['urls'][0]['url'])
                else:
                    hyperlinks.append('#')

for i in range(len(tweet)):
    if hyperlinks[i] == '0' and 'https://' in  tweet[i]:
        somet = tweet[i].find("https://")
        hyperlinks[i] = tweet[i][somet::]
        tweet[i] = tweet[i].replace(hyperlinks[i],' ')
        

for i in range(len(tweet)):
    if hyperlinks[i] != '0':
        somet = tweet[i].find("https://")
        hyperlinks[i] = tweet[i][somet::]
        tweet[i] = tweet[i].replace(hyperlinks[i],' ')
        
df = pd.DataFrame({"Screen Name":screennames_twitter,"Tweets":tweet,"Timeframe":tweets_dates,"Links":hyperlinks})
df.to_csv('All-Tweets.csv',index=False)   
df.sort_values(by=['Timeframe'], inplace=True, ascending=False)
df = df[df["Links"] != '#']
df = df.reset_index(drop=True)
df
# Out:
#          Screen Name                                             Tweets  \
# 0            @CDCgov  DYK: There’s no data to suggest that mosquito ...
# 1    @CovidIndiaSeva  Kindly refer to the following link for #COVID1...
# 2            @CDCgov  Rhode Island child care programs that followed...
# 3    @CovidIndiaSeva  As of today, there are 1549 Dedicated #COVID19...
# 4    @CovidIndiaSeva  The yellow colour on @SetuAarogya signifies mo...
# ..               ...                                                ...
# 101          @CDCgov  A new report in @CDCMMWR shows that the rate o...
# 102          @CDCgov  With changes in food availability in some comm...
# 103          @CDCgov  To stop the spread of #COVID19, CDC will conti...
# 104    @narendramodi  In the middle of a spirited fight against the ...
# 105    @COVID19_USA_  531 new recoveries from COVID-19 so far today ...
#
#               Timeframe                                              Links
# 0   2020-08-21 18:48:00   https://t.co/ewCr9zk50a. https://t.co/lCHWwsp8pF
# 1   2020-08-21 17:39:00  https://t.co/giAlsRMmex\n\n#COVID__19 #COVID #...
# 2   2020-08-21 17:04:07  https://t.co/CujHB1oVnJ. @RIHEALTH https://t.c...
# 3   2020-08-21 16:26:00                            https://t.co/6vawRQI0Ph
# 4   2020-08-21 16:10:00                            https://t.co/QIKfi7QIoO
# ..                  ...                                                ...
# 101 2020-08-19 19:31:21   https://t.co/q1mmzSNE6v. https://t.co/fqOezG7jGx
# 102 2020-08-19 18:36:02    https://t.co/nhtDhyNhJy https://t.co/KLbS5mbrBZ
# 103 2020-08-19 17:45:01    https://t.co/0cLnmzAYNm https://t.co/QHFiqaWLwJ
# 104 2020-08-15 06:12:19                            https://t.co/hCOqwMer33
# 105 2020-04-08 19:50:35                                                  .
#
# [106 rows x 4 columns]
